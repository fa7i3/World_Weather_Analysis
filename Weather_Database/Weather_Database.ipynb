# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Import the API key.
from config import weather_api_key
from citipy import citipy
import requests

# %%
## Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
## Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
## Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)
## Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | mazagao
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | naze
# Processing Record 10 of Set 1 | impfondo
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | sitka
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 1 | namibe
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | saint-pierre
# Processing Record 21 of Set 1 | rocha
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | koungou
# Processing Record 24 of Set 1 | beausoleil
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | vila franca do campo
# Processing Record 27 of Set 1 | pekalongan
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | imbituba
# Processing Record 30 of Set 1 | belmonte
# Processing Record 31 of Set 1 | north bend
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | nishihara
# Processing Record 34 of Set 1 | chardara
# Processing Record 35 of Set 1 | vanimo
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | caravelas
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | kalach-na-donu
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | sibolga
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | ust-ordynskiy
# Processing Record 46 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 1 | chalus
# Processing Record 48 of Set 1 | mandalgovi
# Processing Record 49 of Set 1 | hamilton
# Processing Record 50 of Set 1 | lompoc
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | puerto escondido
# Processing Record 3 of Set 2 | shingu
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | beloha
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | rabupura
# Processing Record 13 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | auki
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | gladstone
# Processing Record 18 of Set 2 | lorengau
# Processing Record 19 of Set 2 | marrakesh
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | waingapu
# Processing Record 23 of Set 2 | bonthe
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | santa cruz cabralia
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | port hardy
# Processing Record 28 of Set 2 | luwingu
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | ketchikan
# Processing Record 32 of Set 2 | tautira
# Processing Record 33 of Set 2 | kaniama
# Processing Record 34 of Set 2 | sungairaya
# Processing Record 35 of Set 2 | wanning
# Processing Record 36 of Set 2 | sobolevo
# Processing Record 37 of Set 2 | salimpur
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | inverell
# Processing Record 41 of Set 2 | berlevag
# Processing Record 42 of Set 2 | grand gaube
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | zolochiv
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | wanlaweyn
# Processing Record 47 of Set 2 | richards bay
# Processing Record 48 of Set 2 | lasa
# Processing Record 49 of Set 2 | houma
# Processing Record 50 of Set 2 | ilulissat
# Processing Record 1 of Set 3 | clovis
# Processing Record 2 of Set 3 | sao filipe
# Processing Record 3 of Set 3 | cayenne
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 3 | peniche
# Processing Record 8 of Set 3 | santa rosa
# Processing Record 9 of Set 3 | los llanos de aridane
# Processing Record 10 of Set 3 | aykhal
# Processing Record 11 of Set 3 | yulara
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | coruripe
# Processing Record 17 of Set 3 | faya
# Processing Record 18 of Set 3 | basa
# Processing Record 19 of Set 3 | tommot
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | koroni
# Processing Record 22 of Set 3 | new norfolk
# Processing Record 23 of Set 3 | montepuez
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 3 | bubaque
# Processing Record 26 of Set 3 | hirara
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | leningradskiy
# Processing Record 29 of Set 3 | berdigestyakh
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | poya
# Processing Record 32 of Set 3 | nuuk
# Processing Record 33 of Set 3 | dalvik
# Processing Record 34 of Set 3 | sandakan
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | alice springs
# Processing Record 38 of Set 3 | eureka
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | arlit
# Processing Record 41 of Set 3 | kiama
# Processing Record 42 of Set 3 | avera
# Processing Record 43 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 3 | hilo
# Processing Record 45 of Set 3 | lokachi
# Processing Record 46 of Set 3 | olafsvik
# Processing Record 47 of Set 3 | la paz
# Processing Record 48 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 3 | shelburne
# Processing Record 50 of Set 3 | saskylakh
# Processing Record 1 of Set 4 | qianan
# Processing Record 2 of Set 4 | bonavista
# Processing Record 3 of Set 4 | sattahip
# Processing Record 4 of Set 4 | krasnoselkup
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | lerwick
# Processing Record 7 of Set 4 | ancud
# Processing Record 8 of Set 4 | srivardhan
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 4 | sambava
# Processing Record 13 of Set 4 | isangel
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | whitianga
# Processing Record 16 of Set 4 | lieksa
# Processing Record 17 of Set 4 | kabelvag
# Processing Record 18 of Set 4 | agadez
# Processing Record 19 of Set 4 | slave lake
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | norman wells
# Processing Record 22 of Set 4 | maceio
# Processing Record 23 of Set 4 | grindavik
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | mount isa
# Processing Record 26 of Set 4 | sabaudia
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | tabas
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | salekhard
# Processing Record 31 of Set 4 | luba
# Processing Record 32 of Set 4 | tuatapere
# Processing Record 33 of Set 4 | margate
# Processing Record 34 of Set 4 | tabou
# Processing Record 35 of Set 4 | haines junction
# Processing Record 36 of Set 4 | fermoy
# Processing Record 37 of Set 4 | sola
# Processing Record 38 of Set 4 | karacabey
# Processing Record 39 of Set 4 | avarua
# Processing Record 40 of Set 4 | port alfred
# Processing Record 41 of Set 4 | port hedland
# Processing Record 42 of Set 4 | yar-sale
# Processing Record 43 of Set 4 | chernyshevskiy
# Processing Record 44 of Set 4 | lagos
# Processing Record 45 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 4 | dzaoudzi
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | nioro
# Processing Record 50 of Set 4 | nome
# Processing Record 1 of Set 5 | prainha
# Processing Record 2 of Set 5 | dwarka
# Processing Record 3 of Set 5 | lodwar
# Processing Record 4 of Set 5 | ashland
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | midyat
# Processing Record 7 of Set 5 | port shepstone
# Processing Record 8 of Set 5 | kampot
# Processing Record 9 of Set 5 | sayyan
# Processing Record 10 of Set 5 | aswan
# Processing Record 11 of Set 5 | hauterive
# Processing Record 12 of Set 5 | shangzhi
# Processing Record 13 of Set 5 | aasiaat
# Processing Record 14 of Set 5 | emerald
# Processing Record 15 of Set 5 | urubicha
# Processing Record 16 of Set 5 | tessalit
# Processing Record 17 of Set 5 | broken hill
# Processing Record 18 of Set 5 | tucano
# Processing Record 19 of Set 5 | palana
# Processing Record 20 of Set 5 | mount vernon
# Processing Record 21 of Set 5 | geraldton
# Processing Record 22 of Set 5 | shenjiamen
# Processing Record 23 of Set 5 | gunnedah
# Processing Record 24 of Set 5 | atbasar
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | chuy
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | sehore
# Processing Record 30 of Set 5 | aquiraz
# Processing Record 31 of Set 5 | bela palanka
# Processing Record 32 of Set 5 | arraial do cabo
# Processing Record 33 of Set 5 | lata
# Processing Record 34 of Set 5 | rawson
# Processing Record 35 of Set 5 | hithadhoo
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | soyo
# Processing Record 38 of Set 5 | ambilobe
# Processing Record 39 of Set 5 | ayorou
# Processing Record 40 of Set 5 | moses lake
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 5 | moyale
# Processing Record 44 of Set 5 | abu kamal
# Processing Record 45 of Set 5 | sechura
# Processing Record 46 of Set 5 | kenai
# Processing Record 47 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 5 | chara
# Processing Record 49 of Set 5 | guerrero negro
# Processing Record 50 of Set 5 | ngunguru
# Processing Record 1 of Set 6 | ondjiva
# Processing Record 2 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 3 of Set 6 | conde
# Processing Record 4 of Set 6 | clyde river
# Processing Record 5 of Set 6 | nelson bay
# Processing Record 6 of Set 6 | synya
# Processing Record 7 of Set 6 | agirish
# Processing Record 8 of Set 6 | awbari
# Processing Record 9 of Set 6 | waterloo
# Processing Record 10 of Set 6 | labuhan
# Processing Record 11 of Set 6 | kavaratti
# Processing Record 12 of Set 6 | seaford
# Processing Record 13 of Set 6 | celendin
# Processing Record 14 of Set 6 | new ross
# Processing Record 15 of Set 6 | portland
# Processing Record 16 of Set 6 | anadyr
# Processing Record 17 of Set 6 | pevek
# Processing Record 18 of Set 6 | carutapera
# Processing Record 19 of Set 6 | chute-aux-outardes
# Processing Record 20 of Set 6 | turiacu
# Processing Record 21 of Set 6 | olinda
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | coquimbo
# Processing Record 24 of Set 6 | bathsheba
# Processing Record 25 of Set 6 | yakeshi
# Processing Record 26 of Set 6 | naica
# Processing Record 27 of Set 6 | pingliang
# Processing Record 28 of Set 6 | melfort
# Processing Record 29 of Set 6 | nouadhibou
# Processing Record 30 of Set 6 | amurzet
# Processing Record 31 of Set 6 | kamenka
# Processing Record 32 of Set 6 | flinders
# Processing Record 33 of Set 6 | san patricio
# Processing Record 34 of Set 6 | urucara
# Processing Record 35 of Set 6 | itarema
# Processing Record 36 of Set 6 | loiza
# Processing Record 37 of Set 6 | waipawa
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | guarapari
# Processing Record 40 of Set 6 | bombay
# Processing Record 41 of Set 6 | cosala
# Processing Record 42 of Set 6 | samarai
# Processing Record 43 of Set 6 | hvolsvollur
# Processing Record 44 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 6 | cairns
# Processing Record 46 of Set 6 | shimoda
# Processing Record 47 of Set 6 | barwaha
# City not found. Skipping...
# Processing Record 48 of Set 6 | devils lake
# Processing Record 49 of Set 6 | wadi maliz
# Processing Record 50 of Set 6 | regina
# Processing Record 1 of Set 7 | la rioja
# Processing Record 2 of Set 7 | calvinia
# Processing Record 3 of Set 7 | sisimiut
# Processing Record 4 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 7 | pacifica
# Processing Record 6 of Set 7 | saint-paul
# Processing Record 7 of Set 7 | alto araguaia
# Processing Record 8 of Set 7 | huangnihe
# Processing Record 9 of Set 7 | beringovskiy
# Processing Record 10 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 7 | constantine
# Processing Record 12 of Set 7 | san ramon
# Processing Record 13 of Set 7 | fairbanks
# Processing Record 14 of Set 7 | savinka
# Processing Record 15 of Set 7 | assiniboia
# Processing Record 16 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 7 | korla
# Processing Record 18 of Set 7 | devonport
# Processing Record 19 of Set 7 | namatanai
# Processing Record 20 of Set 7 | malanje
# Processing Record 21 of Set 7 | praia da vitoria
# Processing Record 22 of Set 7 | havre-saint-pierre
# Processing Record 23 of Set 7 | talnakh
# Processing Record 24 of Set 7 | riachao
# Processing Record 25 of Set 7 | xuanhua
# Processing Record 26 of Set 7 | saldanha
# Processing Record 27 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 7 | jamame
# Processing Record 29 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 30 of Set 7 | khorramshahr
# Processing Record 31 of Set 7 | mersing
# Processing Record 32 of Set 7 | el badari
# City not found. Skipping...
# Processing Record 33 of Set 7 | messina
# Processing Record 34 of Set 7 | albemarle
# Processing Record 35 of Set 7 | hamadan
# Processing Record 36 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 7 | ola
# Processing Record 38 of Set 7 | acapulco
# Processing Record 39 of Set 7 | fez
# Processing Record 40 of Set 7 | bredasdorp
# Processing Record 41 of Set 7 | ternate
# Processing Record 42 of Set 7 | funadhoo
# Processing Record 43 of Set 7 | kirakira
# Processing Record 44 of Set 7 | north myrtle beach
# Processing Record 45 of Set 7 | lumberton
# Processing Record 46 of Set 7 | zhangzhou
# Processing Record 47 of Set 7 | hasaki
# Processing Record 48 of Set 7 | san andres
# Processing Record 49 of Set 7 | urumqi
# Processing Record 50 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | viedma
# Processing Record 2 of Set 8 | chumphon
# Processing Record 3 of Set 8 | half moon bay
# Processing Record 4 of Set 8 | bollnas
# Processing Record 5 of Set 8 | verkhnevilyuysk
# Processing Record 6 of Set 8 | casma
# Processing Record 7 of Set 8 | puerto leguizamo
# Processing Record 8 of Set 8 | fort nelson
# Processing Record 9 of Set 8 | arman
# Processing Record 10 of Set 8 | tibati
# Processing Record 11 of Set 8 | pandan
# Processing Record 12 of Set 8 | mount gambier
# Processing Record 13 of Set 8 | saint george
# Processing Record 14 of Set 8 | peterhead
# Processing Record 15 of Set 8 | dali
# Processing Record 16 of Set 8 | port-gentil
# Processing Record 17 of Set 8 | bodhan
# Processing Record 18 of Set 8 | zaysan
# Processing Record 19 of Set 8 | niigata
# Processing Record 20 of Set 8 | muisne
# Processing Record 21 of Set 8 | araouane
# Processing Record 22 of Set 8 | hudson bay
# Processing Record 23 of Set 8 | langsa
# Processing Record 24 of Set 8 | sao joao da barra
# Processing Record 25 of Set 8 | conceicao do araguaia
# Processing Record 26 of Set 8 | ixtapa
# Processing Record 27 of Set 8 | tiznit
# Processing Record 28 of Set 8 | jawhar
# Processing Record 29 of Set 8 | dhidhdhoo
# Processing Record 30 of Set 8 | belaya gora
# Processing Record 31 of Set 8 | onokhoy
# Processing Record 32 of Set 8 | santa rosalia
# Processing Record 33 of Set 8 | ust-nera
# Processing Record 34 of Set 8 | ramban
# Processing Record 35 of Set 8 | cap malheureux
# Processing Record 36 of Set 8 | alapur
# Processing Record 37 of Set 8 | raton
# Processing Record 38 of Set 8 | zhigansk
# Processing Record 39 of Set 8 | moctezuma
# Processing Record 40 of Set 8 | grand-bourg
# Processing Record 41 of Set 8 | shubarkuduk
# Processing Record 42 of Set 8 | tsumeb
# Processing Record 43 of Set 8 | botelhos
# Processing Record 44 of Set 8 | tevaitoa
# Processing Record 45 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 8 | kaseda
# Processing Record 47 of Set 8 | campeche
# Processing Record 48 of Set 8 | fort smith
# Processing Record 49 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 8 | touros
# Processing Record 1 of Set 9 | kahului
# Processing Record 2 of Set 9 | pemangkat
# Processing Record 3 of Set 9 | byron bay
# Processing Record 4 of Set 9 | dingle
# Processing Record 5 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 9 | pocone
# Processing Record 7 of Set 9 | cordoba
# Processing Record 8 of Set 9 | yumen
# Processing Record 9 of Set 9 | general pico
# Processing Record 10 of Set 9 | saint anthony
# Processing Record 11 of Set 9 | tongliao
# Processing Record 12 of Set 9 | baytown
# Processing Record 13 of Set 9 | luganville
# Processing Record 14 of Set 9 | storforshei
# Processing Record 15 of Set 9 | yining
# Processing Record 16 of Set 9 | tecoanapa
# Processing Record 17 of Set 9 | marawi
# Processing Record 18 of Set 9 | omboue
# Processing Record 19 of Set 9 | egvekinot
# Processing Record 20 of Set 9 | pimentel
# Processing Record 21 of Set 9 | altay
# Processing Record 22 of Set 9 | narsaq
# Processing Record 23 of Set 9 | matara
# Processing Record 24 of Set 9 | zyryanka
# Processing Record 25 of Set 9 | akureyri
# Processing Record 26 of Set 9 | charters towers
# Processing Record 27 of Set 9 | ekibastuz
# Processing Record 28 of Set 9 | les cayes
# Processing Record 29 of Set 9 | twentynine palms
# Processing Record 30 of Set 9 | lesogorsk
# Processing Record 31 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 9 | meiganga
# Processing Record 33 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 9 | salta
# Processing Record 35 of Set 9 | anloga
# Processing Record 36 of Set 9 | lazaro cardenas
# Processing Record 37 of Set 9 | chumikan
# Processing Record 38 of Set 9 | seoul
# Processing Record 39 of Set 9 | bellevue
# Processing Record 40 of Set 9 | mackay
# Processing Record 41 of Set 9 | ierapetra
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | general roca
# Processing Record 44 of Set 9 | storsteinnes
# Processing Record 45 of Set 9 | magaria
# Processing Record 46 of Set 9 | nalvo
# Processing Record 47 of Set 9 | vestmannaeyjar
# Processing Record 48 of Set 9 | batagay-alyta
# Processing Record 49 of Set 9 | russell
# Processing Record 50 of Set 9 | santa isabel
# Processing Record 1 of Set 10 | pangoa
# Processing Record 2 of Set 10 | kochkurovo
# Processing Record 3 of Set 10 | aracuai
# Processing Record 4 of Set 10 | ust-tsilma
# Processing Record 5 of Set 10 | stolin
# Processing Record 6 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 7 of Set 10 | venado tuerto
# Processing Record 8 of Set 10 | hovd
# Processing Record 9 of Set 10 | prieska
# Processing Record 10 of Set 10 | san policarpo
# Processing Record 11 of Set 10 | burnie
# Processing Record 12 of Set 10 | pilar
# Processing Record 13 of Set 10 | hofn
# Processing Record 14 of Set 10 | chihuahua
# Processing Record 15 of Set 10 | kudahuvadhoo
# Processing Record 16 of Set 10 | edremit
# Processing Record 17 of Set 10 | beyneu
# Processing Record 18 of Set 10 | madera
# Processing Record 19 of Set 10 | mehran
# Processing Record 20 of Set 10 | pisco
# Processing Record 21 of Set 10 | montrose
# Processing Record 22 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 10 | san vicente
# Processing Record 24 of Set 10 | opuwo
# Processing Record 25 of Set 10 | stornoway
# Processing Record 26 of Set 10 | goure
# Processing Record 27 of Set 10 | mahebourg
# Processing Record 28 of Set 10 | aberdeen
# Processing Record 29 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 10 | makakilo city
# Processing Record 31 of Set 10 | penticton
# Processing Record 32 of Set 10 | inyonga
# Processing Record 33 of Set 10 | carlagan
# Processing Record 34 of Set 10 | kinarut
# Processing Record 35 of Set 10 | ahipara
# Processing Record 36 of Set 10 | dalupirip
# Processing Record 37 of Set 10 | asau
# Processing Record 38 of Set 10 | lodja
# Processing Record 39 of Set 10 | zaplyusye
# City not found. Skipping...
# Processing Record 40 of Set 10 | uige
# Processing Record 41 of Set 10 | sydney
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | raudeberg
# Processing Record 44 of Set 10 | joinville
# Processing Record 45 of Set 10 | manali
# Processing Record 46 of Set 10 | dombas
# Processing Record 47 of Set 10 | apodi
# Processing Record 48 of Set 10 | sciacca
# Processing Record 49 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 10 | biak
# Processing Record 1 of Set 11 | mareeba
# Processing Record 2 of Set 11 | noumea
# Processing Record 3 of Set 11 | kilindoni
# Processing Record 4 of Set 11 | roald
# Processing Record 5 of Set 11 | dzhankoy
# Processing Record 6 of Set 11 | wajir
# Processing Record 7 of Set 11 | necochea
# Processing Record 8 of Set 11 | uarini
# Processing Record 9 of Set 11 | da nang
# Processing Record 10 of Set 11 | high level
# Processing Record 11 of Set 11 | zeya
# Processing Record 12 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 11 | bunia
# Processing Record 14 of Set 11 | namie
# Processing Record 15 of Set 11 | hailey
# Processing Record 16 of Set 11 | kokuy
# Processing Record 17 of Set 11 | hambantota
# Processing Record 18 of Set 11 | dogondoutchi
# Processing Record 19 of Set 11 | honningsvag
# Processing Record 20 of Set 11 | souillac
# Processing Record 21 of Set 11 | ciudad guayana
# Processing Record 22 of Set 11 | lavrentiya
# Processing Record 23 of Set 11 | trinidad
# Processing Record 24 of Set 11 | raska
# Processing Record 25 of Set 11 | tashtyp
# Processing Record 26 of Set 11 | zahirabad
# Processing Record 27 of Set 11 | wlodawa
# Processing Record 28 of Set 11 | massaguet
# Processing Record 29 of Set 11 | tlahualilo
# City not found. Skipping...
# Processing Record 30 of Set 11 | mecca
# Processing Record 31 of Set 11 | mgandu
# Processing Record 32 of Set 11 | atambua
# Processing Record 33 of Set 11 | zhanaozen
# Processing Record 34 of Set 11 | san cristobal
# Processing Record 35 of Set 11 | san jeronimo
# Processing Record 36 of Set 11 | arona
# Processing Record 37 of Set 11 | coihueco
# Processing Record 38 of Set 11 | fare
# Processing Record 39 of Set 11 | thap khlo
# Processing Record 40 of Set 11 | dezhou
# Processing Record 41 of Set 11 | salaga
# Processing Record 42 of Set 11 | orangeburg
# Processing Record 43 of Set 11 | havelock
# Processing Record 44 of Set 11 | waitati
# Processing Record 45 of Set 11 | chabahar
# Processing Record 46 of Set 11 | nyurba
# Processing Record 47 of Set 11 | yerbogachen
# Processing Record 48 of Set 11 | saint-francois
# Processing Record 49 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 50 of Set 11 | laguna
# Processing Record 1 of Set 12 | chazuta
# Processing Record 2 of Set 12 | mormugao
# Processing Record 3 of Set 12 | pindiga
# Processing Record 4 of Set 12 | gracac
# Processing Record 5 of Set 12 | sorkjosen
# Processing Record 6 of Set 12 | tevriz
# Processing Record 7 of Set 12 | huangchuan
# Processing Record 8 of Set 12 | baykit
# Processing Record 9 of Set 12 | teguise
# Processing Record 10 of Set 12 | san antonio
# Processing Record 11 of Set 12 | dakar
# Processing Record 12 of Set 12 | hervey bay
# Processing Record 13 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 12 | sistranda
# Processing Record 15 of Set 12 | misratah
# Processing Record 16 of Set 12 | abong mbang
# Processing Record 17 of Set 12 | sioux lookout
# Processing Record 18 of Set 12 | guane
# Processing Record 19 of Set 12 | prachuap khiri khan
# Processing Record 20 of Set 12 | ayan
# Processing Record 21 of Set 12 | namwala
# Processing Record 22 of Set 12 | catuday
# Processing Record 23 of Set 12 | vostok
# Processing Record 24 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 25 of Set 12 | hit
# Processing Record 26 of Set 12 | camacha
# Processing Record 27 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 28 of Set 12 | takoradi
# Processing Record 29 of Set 12 | carauari
# Processing Record 30 of Set 12 | codrington
# Processing Record 31 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 32 of Set 12 | teguldet
# Processing Record 33 of Set 12 | kautokeino
# Processing Record 34 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 12 | bonga
# Processing Record 36 of Set 12 | razole
# Processing Record 37 of Set 12 | broome
# Processing Record 38 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 39 of Set 12 | llata
# Processing Record 40 of Set 12 | itacarambi
# Processing Record 41 of Set 12 | papara
# Processing Record 42 of Set 12 | pundaguitan
# Processing Record 43 of Set 12 | goderich
# Processing Record 44 of Set 12 | kununurra
# Processing Record 45 of Set 12 | santa luzia
# Processing Record 46 of Set 12 | norton shores
# Processing Record 47 of Set 12 | kampong thum
# Processing Record 48 of Set 12 | betioky
# Processing Record 49 of Set 12 | comodoro rivadavia
# Processing Record 50 of Set 12 | muriwai beach
# Processing Record 1 of Set 13 | hohhot
# Processing Record 2 of Set 13 | marquette
# Processing Record 3 of Set 13 | kloulklubed
# Processing Record 4 of Set 13 | prince albert
# Processing Record 5 of Set 13 | iqaluit
# Processing Record 6 of Set 13 | metu
# Processing Record 7 of Set 13 | anguillara sabazia
# Processing Record 8 of Set 13 | nago
# Processing Record 9 of Set 13 | the valley
# Processing Record 10 of Set 13 | ishigaki
# Processing Record 11 of Set 13 | taunggyi
# Processing Record 12 of Set 13 | nizhniy ingash
# Processing Record 13 of Set 13 | vardo
# Processing Record 14 of Set 13 | shalya
# Processing Record 15 of Set 13 | muhos
# Processing Record 16 of Set 13 | havoysund
# Processing Record 17 of Set 13 | sembe
# Processing Record 18 of Set 13 | quang ngai
# Processing Record 19 of Set 13 | engel-yurt
# Processing Record 20 of Set 13 | belturbet
# Processing Record 21 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 13 | pochutla
# Processing Record 23 of Set 13 | barentu
# Processing Record 24 of Set 13 | mookane
# Processing Record 25 of Set 13 | madingou
# Processing Record 26 of Set 13 | kisangani
# Processing Record 27 of Set 13 | maracacume
# Processing Record 28 of Set 13 | kollumerland
# City not found. Skipping...
# Processing Record 29 of Set 13 | nemuro
# Processing Record 30 of Set 13 | chitral
# Processing Record 31 of Set 13 | lokosovo
# Processing Record 32 of Set 13 | quatre cocos
# Processing Record 33 of Set 13 | pangnirtung
# Processing Record 34 of Set 13 | grootfontein
# Processing Record 35 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 13 | sorland
# Processing Record 37 of Set 13 | prince rupert
# Processing Record 38 of Set 13 | kendari
# Processing Record 39 of Set 13 | kaa-khem
# Processing Record 40 of Set 13 | rawah
# Processing Record 41 of Set 13 | gazli
# Processing Record 42 of Set 13 | hokitika
# Processing Record 43 of Set 13 | ayr
# Processing Record 44 of Set 13 | niort
# Processing Record 45 of Set 13 | pirovskoye
# Processing Record 46 of Set 13 | huesca
# Processing Record 47 of Set 13 | cervo
# Processing Record 48 of Set 13 | macapa
# Processing Record 49 of Set 13 | paamiut
# Processing Record 50 of Set 13 | malartic
# Processing Record 1 of Set 14 | buchanan
# Processing Record 2 of Set 14 | kongolo
# Processing Record 3 of Set 14 | nabire
# Processing Record 4 of Set 14 | marsa matruh
# Processing Record 5 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 14 | semey
# Processing Record 7 of Set 14 | taoudenni
# Processing Record 8 of Set 14 | salym
# Processing Record 9 of Set 14 | birnin kebbi
# Processing Record 10 of Set 14 | sungaipenuh
# Processing Record 11 of Set 14 | tilichiki
# Processing Record 12 of Set 14 | abu samrah
# Processing Record 13 of Set 14 | old saybrook
# Processing Record 14 of Set 14 | ponta delgada
# Processing Record 15 of Set 14 | kondagaon
# Processing Record 16 of Set 14 | klaksvik
# Processing Record 17 of Set 14 | polovinnoye
# Processing Record 18 of Set 14 | pacific grove
# Processing Record 19 of Set 14 | mwinilunga
# Processing Record 20 of Set 14 | quelimane
# Processing Record 21 of Set 14 | turukhansk
# Processing Record 22 of Set 14 | beboto
# Processing Record 23 of Set 14 | kismayo
# Processing Record 24 of Set 14 | abha
# Processing Record 25 of Set 14 | mangrol
# Processing Record 26 of Set 14 | ostrovnoy
# Processing Record 27 of Set 14 | santa cruz
# Processing Record 28 of Set 14 | mahates
# Processing Record 29 of Set 14 | chanal
# Processing Record 30 of Set 14 | oxbow
# Processing Record 31 of Set 14 | jaru
# Processing Record 32 of Set 14 | vuktyl
# Processing Record 33 of Set 14 | stuttgart
# Processing Record 34 of Set 14 | shellbrook
# Processing Record 35 of Set 14 | vao
# Processing Record 36 of Set 14 | ocos
# Processing Record 37 of Set 14 | muhldorf
# Processing Record 38 of Set 14 | port macquarie
# Processing Record 39 of Set 14 | buala
# Processing Record 40 of Set 14 | macau
# Processing Record 41 of Set 14 | gomel
# Processing Record 42 of Set 14 | rio gallegos
# Processing Record 43 of Set 14 | san quintin
# Processing Record 44 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 14 | kutum
# Processing Record 46 of Set 14 | bandiagara
# Processing Record 47 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 14 | puerto madryn
# Processing Record 49 of Set 14 | valparaiso
# Processing Record 50 of Set 14 | pombas
# Processing Record 1 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 2 of Set 15 | puerto gaitan
# Processing Record 3 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 4 of Set 15 | finschhafen
# Processing Record 5 of Set 15 | pietarsaari
# Processing Record 6 of Set 15 | talcahuano
# Processing Record 7 of Set 15 | baherden
# Processing Record 8 of Set 15 | warmbad
# Processing Record 9 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 10 of Set 15 | tomatlan
# Processing Record 11 of Set 15 | trincomalee
# Processing Record 12 of Set 15 | sinnamary
# Processing Record 13 of Set 15 | kemijarvi
# Processing Record 14 of Set 15 | plerin
# Processing Record 15 of Set 15 | dudinka
# Processing Record 16 of Set 15 | pangody
# Processing Record 17 of Set 15 | clonakilty
# Processing Record 18 of Set 15 | varkkallai
# Processing Record 19 of Set 15 | maltahohe
# Processing Record 20 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 15 | balad
# Processing Record 22 of Set 15 | trelew
# Processing Record 23 of Set 15 | ulaangom
# Processing Record 24 of Set 15 | pauini
# Processing Record 25 of Set 15 | yara
# Processing Record 26 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 27 of Set 15 | porosozero
# Processing Record 28 of Set 15 | el coyote
# Processing Record 29 of Set 15 | mathbaria
# Processing Record 30 of Set 15 | birjand
# Processing Record 31 of Set 15 | presidencia roque saenz pena
# Processing Record 32 of Set 15 | pafos
# Processing Record 33 of Set 15 | gua musang
# Processing Record 34 of Set 15 | rio grande
# Processing Record 35 of Set 15 | kajaani
# Processing Record 36 of Set 15 | semirom
# Processing Record 37 of Set 15 | muromtsevo
# Processing Record 38 of Set 15 | vidim
# Processing Record 39 of Set 15 | henties bay
# Processing Record 40 of Set 15 | rondonopolis
# Processing Record 41 of Set 15 | dong hoi
# Processing Record 42 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 15 | chelno-vershiny
# Processing Record 44 of Set 15 | kashi
# Processing Record 45 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 15 | aitape
# Processing Record 47 of Set 15 | bilma
# Processing Record 48 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 49 of Set 15 | namikupa
# Processing Record 50 of Set 15 | koumac
# Processing Record 1 of Set 16 | amahai
# Processing Record 2 of Set 16 | plock
# Processing Record 3 of Set 16 | tripoli
# Processing Record 4 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 16 | manzhouli
# Processing Record 6 of Set 16 | isabela
# Processing Record 7 of Set 16 | goksun
# Processing Record 8 of Set 16 | tura
# Processing Record 9 of Set 16 | atrauli
# Processing Record 10 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 16 | salihorsk
# Processing Record 12 of Set 16 | nioki
# Processing Record 13 of Set 16 | bobo dioulasso
# Processing Record 14 of Set 16 | maniitsoq
# Processing Record 15 of Set 16 | yamethin
# Processing Record 16 of Set 16 | verkhnyaya khava
# Processing Record 17 of Set 16 | nizwa
# Processing Record 18 of Set 16 | aklavik
# Processing Record 19 of Set 16 | alyangula
# Processing Record 20 of Set 16 | ceres
# Processing Record 21 of Set 16 | williston
# Processing Record 22 of Set 16 | riviera beach
# Processing Record 23 of Set 16 | porto novo
# Processing Record 24 of Set 16 | mikhaylov
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
## Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     80.56        89          82
# 1   East London      ZA -33.0153   27.9116     61.74        82           0
# 2       Mazagao      BR  -0.1150  -51.2894     89.65        70          46
# 3       Rikitea      PF -23.1203 -134.9692     73.08        70          26
# 4       Ushuaia      AR -54.8000  -68.3000     40.62        81           0
# 5   Provideniya      RU  64.3833 -173.3000     35.40        96          99
# 6       Qaanaaq      GL  77.4840  -69.3632     30.43        66          48
# 7          Naze      JP  28.3667  129.4833     74.32        87         100
# 8      Impfondo      CG   1.6381   18.0667     78.58        73         100
# 9  Punta Arenas      CL -53.1500  -70.9167     39.31        81           0
#
#    Wind Speed Current Description
# 0        5.99       broken clouds
# 1        8.05           clear sky
# 2        4.59    scattered clouds
# 3        9.51    scattered clouds
# 4        4.61           clear sky
# 5        5.57          light rain
# 6        1.32    scattered clouds
# 7       13.42     overcast clouds
# 8        2.44     overcast clouds
# 9        6.91           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
